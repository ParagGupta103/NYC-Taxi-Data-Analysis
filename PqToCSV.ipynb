# %%
import pandas as pd

# %%
df = pd.read_csv("data/uber_data.csv")
df.tail()
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 99995         1  2016-03-01 06:17:10   2016-03-01 06:22:15                1
# 99996         1  2016-03-01 06:17:10   2016-03-01 06:32:41                1
# 99997         1  2016-03-01 06:17:10   2016-03-01 06:37:23                1
# 99998         2  2016-03-01 06:17:10   2016-03-01 06:22:09                1
# 99999         1  2016-03-01 06:17:11   2016-03-01 06:22:00                1
#
#        trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 99995           0.50        -73.990898        40.750519           1
# 99996           3.40        -74.014488        40.718296           1
# 99997           9.70        -73.963379        40.774097           1
# 99998           0.92        -73.984901        40.763111           1
# 99999           1.00        -73.990685        40.750473           1
#
#       store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df2 = pd.read_parquet('data/fhvhv_tripdata_2024-05.parquet')

# %%
df2.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0005               B03406                 None
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2024-04-30 23:55:50 2024-04-30 23:59:00 2024-05-01 00:00:36
# 1 2024-05-01 00:41:32 2024-05-01 00:47:40 2024-05-01 00:49:40
# 2 2024-05-01 00:09:01 2024-05-01 00:10:51 2024-05-01 00:11:31
# 3 2024-05-01 00:25:43 2024-05-01 00:48:00 2024-05-01 00:48:30
# 4 2024-05-01 00:00:08                 NaT 2024-05-01 00:09:29
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  sales_tax  \
# 0 2024-05-01 00:38:21           138            21      18.680  ...       4.48
# ...

# %%
len(df2)
# Out:
# 20704538

# %%
df = df2[:300000]

# %%
df.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0005               B03406                 None
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2024-04-30 23:55:50 2024-04-30 23:59:00 2024-05-01 00:00:36
# 1 2024-05-01 00:41:32 2024-05-01 00:47:40 2024-05-01 00:49:40
# 2 2024-05-01 00:09:01 2024-05-01 00:10:51 2024-05-01 00:11:31
# 3 2024-05-01 00:25:43 2024-05-01 00:48:00 2024-05-01 00:48:30
# 4 2024-05-01 00:00:08                 NaT 2024-05-01 00:09:29
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  sales_tax  \
# 0 2024-05-01 00:38:21           138            21      18.680  ...       4.48
# ...

# %%
df.to_csv('data/dataset.csv', index=False)

# %%
df.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0005               B03406                 None
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2024-04-30 23:55:50 2024-04-30 23:59:00 2024-05-01 00:00:36
# 1 2024-05-01 00:41:32 2024-05-01 00:47:40 2024-05-01 00:49:40
# 2 2024-05-01 00:09:01 2024-05-01 00:10:51 2024-05-01 00:11:31
# 3 2024-05-01 00:25:43 2024-05-01 00:48:00 2024-05-01 00:48:30
# 4 2024-05-01 00:00:08                 NaT 2024-05-01 00:09:29
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  sales_tax  \
# 0 2024-05-01 00:38:21           138            21      18.680  ...       4.48
# ...

# %%
df.columns
# Out:
# Index(['hvfhs_license_num', 'dispatching_base_num', 'originating_base_num',
#        'request_datetime', 'on_scene_datetime', 'pickup_datetime',
#        'dropoff_datetime', 'PULocationID', 'DOLocationID', 'trip_miles',
#        'trip_time', 'base_passenger_fare', 'tolls', 'bcf', 'sales_tax',
#        'congestion_surcharge', 'airport_fee', 'tips', 'driver_pay',
#        'shared_request_flag', 'shared_match_flag', 'access_a_ride_flag',
#        'wav_request_flag', 'wav_match_flag'],
#       dtype='object')

# %%
filtered_df = df.dropna()

# %%
filtered_df.to_csv('data/dataset.csv', index=False)

# %%
len(filtered_df)
# Out:
# 227111
